# %%
import re

# %%
import pandas as pd

# %%
import csv

# %%
# read csv containing Dengue articles
df = pd.read_csv('TestDengueContent.csv')

# %%
df = df.fillna("")

# %%
print(df.shape)
# Out:
# (479, 4)

# %%
# Regex for publication date
regex_for_publication_date = r"\d{4}-\d{2}-\d{2}"

# %%
regex_for_numbers = re.compile(r'\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*');

# %%
# a number or a number following 'dengue' or 'cases'
# regex_for_numbers1 = re.compile(r'(?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*\s*(?:dengue|cases))|(?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*)')

# %%
# a number or a number following 'dengue' or 'cases' or 'suspected dengue cases' or 'suspected cases'
# regex_for_numbers2 = re.compile(r'(?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*\s*(?:dengue|cases|suspected\sdengue\scases|suspected\+*-scases))|(?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*)')

# %%
# a number following 'dengue' or 'cases' or 'suspected dengue cases' or 'suspected cases'
regex_for_cases = re.compile(r'\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*\s*(?:dengue|cases|suspected\sdengue\scases|suspected\scases)', re.IGNORECASE)

# %%
# regex_for_deaths1 = re.compile(r'\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*\s*(?:deaths|death|people\shave\sdied)')

# %%
# regex_for_deaths = re.compile(r'\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*\s*(?:deaths|death|(?:people\s|patients\s)?(?:have|had)\sdied)')

# %%
# regex_for_deaths = re.compile(r"""
# (?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*) #for numbers
# \s*
# (?:deaths|death|(?:people\s|patients\s)?(?:have|had)?\sdied)
# """, re.VERBOSE)

# %%
# regex for deaths or (TODO move patients to no.of cases)patients
regex_for_deaths = re.compile(r"""
(?:(?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*)|
(?:one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve|thirteen|fourteen|fifteen|sixteen|seventeen|eighteen|nineteen|
(?:(?:(?:twenty|thirty|forty|fifty|sixty|seventy|eighty|ninety)\s*)(?:one|two|three|four|five|six|seven|eight|nine)?)))
\s*
(?:deaths|death|dead(?:people\s*|patients\s*)?(?:have\s*|had\s*)?(?:died|dead)|patients)
""", re.VERBOSE | re.IGNORECASE)

# %%
# TODO handle for "i.e" 
regex_for_sentences = re.compile(r"[^.]*?(?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*\s*(?:dengue|cases|suspected\sdengue\scases|suspected\scases)|(?:(?:(?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*)|(?:one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve|thirteen|fourteen|fifteen|sixteen|seventeen|eighteen|nineteen|(?:(?:(?:twenty|thirty|forty|fifty|sixty|seventy|eighty|ninety)\s*)(?:one|two|three|four|five|six|seven|eight|nine)?)))\s*(?:deaths|death|dead(?:people\s*|patients\s*)?(?:have\s*|had\s*)?(?:died|dead)|patients)))[^.]*\.")

# %%
# regex_for_dates = re.compile(r'(?:\d{4}(?:\.|/|-)\d{1,2}(?:\.|/|-)\d{1,2})|(?:\d{1,2}(?:\.|/|-)\d{1,2}(?:\.|/|-)\d{2,4})|(?:(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|April|May|June|July|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)\s*\d{0,2})', re.IGNORECASE)

# %%
regex_for_dates = re.compile(r'(?:\d{4}(?:\.|/|-)\d{1,2}(?:\.|/|-)\d{1,2})|(?:\d{1,2}(?:\.|/|-)\d{1,2}(?:\.|/|-)\d{2,4})|(?:(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|April|May|June|July|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)\s*\d{0,2})')

# %%
regex_for_districts = re.compile(r'Jaffna|Kilinochchi|Mannar|Mullaitivu|Vavuniya|Puttalam|Kurunegala|Gampaha|Colombo|Kalutara|Anuradhapura|Polonnaruwa|Matale|Kandy|Nuwara\sEliya|Kegalle|Ratnapura|Trincomalee|Batticaloa|Ampara|Badulla|Monaragala|Hambantota|Matara|Galle', re.IGNORECASE)

# %%
def get_sentences(text):
    return regex_for_sentences.findall(text)

# %%
def get_districts(text):
    return regex_for_districts.findall(text)

# %%
def get_deaths(text):
    return regex_for_deaths.findall(text)

# %%
def get_numbers(text):
    return regex_for_numbers.findall(text)

# %%
def get_cases(text):
    return regex_for_cases.findall(text)

# %%
def get_published_date(text):
    return re.search(regex_for_publication_date, text).group()

# %%
def get_dates(text):
    return regex_for_dates.findall(text)

# %%
for index, row in df.iterrows():
    print("Index: "+str(index))
    print("Publication date: "+get_published_date(row['Date']))
    sentences = get_sentences(row['Article_content'])
    print(sentences)
    for sentence in sentences:
        print(sentence)
        get_data(sentence)
    print()
# Out:
# Index: 0
# Publication date: 2018-05-09
# []
#
# Index: 1
# Publication date: 2018-05-09
# []
#
# Index: 2
# Publication date: 2018-05-08
# []
#
# Index: 3
# Publication date: 2018-04-10
# []
#
# Index: 4
# Publication date: 2018-04-06
# []
#
# Index: 5
# Publication date: 2018-04-04
# []
#
# Index: 6
# Publication date: 2018-03-29
# []
#
# Index: 7
# Publication date: 2018-03-28
# []
#
# Index: 8
# Publication date: 2018-03-27
# []
#
# Index: 9
# Publication date: 2018-03-26
# []
#
# Index: 10
# Publication date: 2018-03-22
# []
#
# Index: 11
# Publication date: 2018-03-20
# []
#
# Index: 12
# Publication date: 2018-03-16
# []
#
# Index: 13
# Publication date: 2018-03-15
# []
#
# Index: 14
# Publication date: 2018-03-09
# []
#
# Index: 15
# Publication date: 2018-03-09
# []
#
# Index: 16
# Publication date: 2018-03-09
# []
#
# Index: 17
# Publication date: 2018-03-08
# []
#
# Index: 18
# Publication date: 2018-02-26
# []
#
# Index: 19
# Publication date: 2018-02-21
# ...

# %%
def get_data(text):
    print("Cases: ")
    cases = get_cases(row['Article_content'])
    print(cases)
    
    print("Deaths: ")
    deaths = get_deaths(row['Article_content'])
    print(deaths)
    
    print("Dates: ")
    dates = get_dates(row['Article_content'])
    print(dates)
    
    print("Districts: ")
    districts = get_districts(row['Article_content'])
    print(districts)
    
#     print()

# %%
for index, row in df.iterrows():
    print("Index: "+str(index))
    print("Publication date: "+get_published_date(row['Date']))
    
    sentences = get_sentences(row['Article_content'])
    print(sentences)
    
    print("Numbers: ")
    numbers = get_numbers(row['Article_content'])
    
    print("Cases: ")
    cases = get_cases(row['Article_content'])
    print(cases)
    
    print("Deaths: ")
    deaths = get_deaths(row['Article_content'])
    print(deaths)
    
    print("Dates: ")
    dates = get_dates(row['Article_content'])
    print(dates)
    
    print("Districts: ")
    districts = get_districts(row['Article_content'])
    print(districts)
    
    print()

#     ''.join([i if ord(i) < 128 else ' ' for i in row['Article_content']])
#     re.sub(r'[^\x00-\x7F]',' ', row['Article_content'])
#     df['Season2'] = df['Season'].apply(split_it(x))
# Out:
# Index: 0
# Publication date: 2018-05-09
# []
# Numbers:
# Cases:
# []
# Deaths:
# []
# Dates:
# ['April ', 'April ', 'April ']
# Districts:
# []
#
# Index: 1
# Publication date: 2018-05-09
# []
# Numbers:
# Cases:
# []
# Deaths:
# []
# Dates:
# ['April 14', 'January', 'April 20', 'August 20', 'August 20']
# Districts:
# ['Colombo']
#
# Index: 2
# Publication date: 2018-05-08
# []
# Numbers:
# Cases:
# []
# Deaths:
# []
# Dates:
# ['May ', 'Jan', 'May ', 'May ', 'May ']
# Districts:
# ['Galle', 'Galle']
#
# Index: 3
# Publication date: 2018-04-10
# []
# Numbers:
# Cases:
# []
# Deaths:
# []
# Dates:
# ['March', 'March 20', 'March', 'March', 'March ', 'March']
# Districts:
# ['Kandy']
#
# Index: 4
# Publication date: 2018-04-06
# []
# Numbers:
# Cases:
# []
# Deaths:
# []
# Dates:
# ['Mar', 'June 20']
# Districts:
# []
#
# Index: 5
# Publication date: 2018-04-04
# []
# Numbers:
# Cases:
# []
# Deaths:
# []
# Dates:
# ['May']
# Districts:
# ['Colombo']
#
# Index: 6
# ...

# %%
articles=[]
articles.append({
        'Index':str(index),
        'Publication_date':get_published_date(row['Date']),
        'Numbers':get_numbers(row['Article_content']),
        'Cases':get_cases(row['Article_content']),
        'Deaths':get_deaths(row['Article_content']),
        'Dates': get_dates(row['Article_content']),
        'Districts':get_districts(row['Article_content']),
    })

# %%
import csv

# %%
with open('Regex_output.csv',mode='w') as csv_file:
    fieldnames=['Index','Publication_date','Numbers','Cases','Deaths','Dates','Districts']
    writer=csv.DictWriter(csv_file,fieldnames=fieldnames)

    writer.writeheader()
    for article in articles:
        writer.writerow({'Index':article['Index'],'Publication_date':article['Publication_date'],'Numbers':article['Numbers'],'Cases':article['Cases'],'Deaths':article['Deaths'],'Dates':article['Dates'],'Districts':article['Districts']})
