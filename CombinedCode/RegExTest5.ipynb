# %%
import re

# %%
import pandas as pd

# %%
import csv

# %%
# read csv containing Dengue articles to a dataframe
df = pd.read_csv('TestDengueContent.csv')

# %%
# Fill missing values
df = df.fillna("")

# %%
print(df.shape)
# Out:
# (479, 4)

# %%
# drops duplicate entries
df.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
print(df.shape)
# Out:
# (478, 4)

# %%
# Regex for publication date ####-##-##
regex_for_publication_date = r"\d{4}-\d{2}-\d{2}"

# %%
# a number following 'dengue' or 'cases' or 'suspected dengue cases' or 'suspected cases'
regex_for_cases = re.compile(r'\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*\s*(?:dengue\scases|dengue\sfever\scases|dengue|cases|suspected\sdengue\scases|suspected\scases)', re.IGNORECASE)

# %%
# regex for deaths or patients(TODO move patients to no.of cases)
regex_for_deaths = re.compile(r"""
(?:(?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*)|
(?:one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve|thirteen|fourteen|fifteen|sixteen|seventeen|eighteen|nineteen|
(?:(?:(?:twenty|thirty|forty|fifty|sixty|seventy|eighty|ninety)\s*)(?:one|two|three|four|five|six|seven|eight|nine)?)))
\s*
(?:deaths|death|dead(?:people\s*|patients\s*)?(?:have\s*|had\s*)?(?:died|dead)|patients|dengue\srelated\deaths)
""", re.VERBOSE | re.IGNORECASE)

# %%
# regex to extract sentences having no. of cases/deaths
# TODO handle for "i.e" 
regex_for_sentences = re.compile(r"[^.]*?(?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*\s*(?:dengue|cases|suspected\sdengue\scases|suspected\scases)|(?:(?:(?:\d+(?:(?:,|\s|(?:,\s)|(?:\s,))\d+)*)|(?:one|two|three|four|five|six|seven|eight|nine|ten|eleven|twelve|thirteen|fourteen|fifteen|sixteen|seventeen|eighteen|nineteen|(?:(?:(?:twenty|thirty|forty|fifty|sixty|seventy|eighty|ninety)\s*)(?:one|two|three|four|five|six|seven|eight|nine)?)))\s*(?:deaths|death|dead(?:people\s*|patients\s*)?(?:have\s*|had\s*)?(?:died|dead)|patients)))[^.]*\.")

# %%
# regex for dates
regex_for_dates = re.compile(r"""(?:\d{4}(?:\.|/|-)\d{1,2}(?:\.|/|-)\d{1,2})|                                                                       # dates with format xxxx.xx.xx or xxxx/xx/xx or xxxx-xx-xx (month and date: 1 or 2 digits)
(?:\d{1,2}(?:\.|/|-)\d{1,2}(?:\.|/|-)\d{2,4})|                                                                                                      # dates with format xx.xx.xx where . or / or - used as the seperator, 1 or 2 digits for date or month, 2 or 4 digits for year
(?:(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|April|May|June|July|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)\s*\d{0,2})     # dates with format: month xx (date with 0-2 digits)
""", re.VERBOSE)

# %%
# regex_for_years 20xx
regex_for_years = re.compile(r'\b20(?:\d{2}){1}\b|this\syear')

# %%
# regex for months
regex_for_months = re.compile(r'Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|April|May|June|July|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)')

# %%
# regex for "so far"
regex_for_so_far = re.compile(r'so\sfar')

# %%
# regex for districts
regex_for_districts = re.compile(r'Jaffna|Kilinochchi|Mannar|Mullaitivu|Vavuniya|Puttalam|Kurunegala|Gampaha|Colombo|Kalutara|Anuradhapura|Polonnaruwa|Matale|Kandy|Nuwara\sEliya|Kegalle|Ratnapura|Trincomalee|Trinco|Batticaloa|Ampara|Badulla|Monaragala|Hambantota|Matara|Galle', re.IGNORECASE)

# %%
# regex for provinces
regex_for_provinces = re.compile(r'Western|Central|Eastern|North\sCentral|Northern|North\sWestern|Sabaragamuwa|Southern|Uva')

# %%
# regex for other places/locations
regex_for_places = re.compile(r'Sri Lanka|island|country|countrywide|Meethotamulla|Negombo|Ratmalana|Dangolla|Elpitiya|Beliatte|Hatton|Marakolliya|Gampola|Kalubowila')

# %%
def get_sentences(text):
    return regex_for_sentences.findall(text)

# %%
def get_published_date(text):
    return re.search(regex_for_publication_date, text).group()

# %%
def get_cases(text):
    return regex_for_cases.findall(text)

# %%
def get_deaths(text):
    return regex_for_deaths.findall(text)

# %%
def get_years(text):
    return regex_for_years.findall(text)

# %%
def get_months(text):
    return regex_for_months.findall(text)

# %%
def get_dates(text):
    return regex_for_dates.findall(text)

# %%
def get_so_far(text):
    return regex_for_so_far.findall(text)

# %%
def get_provinces(text):
    return regex_for_provinces.findall(text)

# %%
def get_districts(text):
    return regex_for_districts.findall(text)

# %%
def get_places(text):
    return regex_for_places.findall(text)

# %%
locations=["Meethotamulla","Colombo", "kandy","Anuradhapura","Galle","Matara","Ratmalana","Dangolla","Badulla","Elpitiya","Beliatte","Hatton","Marakolliya","Gampola","Kalubowila","Puttalam",]

# %%
for index, row in df.iterrows():
    print("Index: "+str(index))
#     print("Publication date: "+get_published_date(row['Date']))
    sentences = get_sentences(row['Article_content'])
#     print(sentences)
    for sentence in sentences:
        print(sentence)
#         get_data(sentence)
        
        
        print(str(index))
        print(get_published_date(row['Date']))
#         print(sentence.encode("utf-8"))
#         print(get_numbers(sentence))
        print(get_cases(sentence))
        print(get_deaths(sentence))
        print(get_years(sentence))
        print(get_months(sentence))
        print(get_dates(sentence))
        print(get_so_far(sentence))
        print(get_provinces(sentence))
        print(get_districts(sentence))
        print(get_places(sentence))
           
        
    print()
# Out:
# Index: 0
#
# Index: 1
#
# Index: 2
#
# Index: 3
#
# Index: 4
#
# Index: 5
#
# Index: 6
#
# Index: 7
#
# Index: 8
#
# Index: 9
#
# Index: 10
#
# Index: 11
#
# Index: 12
#
# Index: 13
#
# Index: 14
#
# Index: 15
#
# Index: 16
#
# Index: 17
#
# Index: 18
#
# Index: 19
# Enduring support of the respective authorities and positive contribution of the UA staff members across the branch network has led Union Manushyathwaya to successfully conduct over 50 dengue awareness programmes, over 100 thalassemia awareness programmes and 45 diabetes awareness programmes.
# 19
# 2018-02-21
# ['50 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 20
# � �Haemophilia�This is a very rare disease, with only around 2000 patients being present in all of Sri Lanka.
# 20
# 2018-02-09
# []
# ['2000 patients']
# ['2000']
# []
# []
# []
# []
# []
# ['Sri Lanka']
#
# Index: 21
#
# Index: 22
#
# Index: 23
#
# Index: 24
#
# Index: 25
#
# Index: 26
#
# Index: 27
# The intermittent rains experienced in many parts of the country right now has increased the threat of a dengue outbreak, while the number of dengue cases reported in the first five weeks of 2018 stood at 6,203 by today, with five deaths.
# 27
# 2018-02-02
# []
# ['five deaths']
# ['2018']
# []
# []
# []
# []
# []
# ['country']
# The Government Epidemiology Unit (GEU) announced today that during the last 12 months of the year 2017, 184,442 suspected dengue cases have been reported to the Epidemiology Unit throughout the island.
# 27
# 2018-02-02
# ['2017, 184,442 suspected dengue cases']
# []
# ['2017']
# []
# []
# []
# []
# []
# ['island']
#
# Index: 28
#
# Index: 29
#
# Index: 30
#
# Index: 31
#
# Index: 32
#
# Index: 33
#
# Index: 34
#
# Index: 35
#
# Index: 36
#
# Index: 37
#
# Index: 38
#
# Index: 39
#
# Index: 40
#
# Index: 41
#
# Index: 42
#
# Index: 43
#
# Index: 44
#
# Index: 45
#
# Index: 46
#
# Index: 47
#
# Index: 48
#
# Index: 49
#
# Index: 50
#
# Index: 51
#
# Index: 52
#
# Index: 53
#
# Index: 54
#
# Index: 55
#
# Index: 56
#
# Index: 57
#
# Index: 58
#
# Index: 59
#  As a result, the accuracy of these statistics is very low and only around 100 out of 150 patients reported is actually having Dengue fever,� they elaborated.
# 59
# 2017-11-21
# []
# ['150 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 60
#  As a result, the accuracy of these statistics is very low and only around 100 out of 150 patients reported is actually having Dengue fever,� they elaborated.
# 60
# 2017-11-21
# []
# ['150 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 61
#
# Index: 62
#
# Index: 63
#
# Index: 64
#
# Index: 65
#
# Index: 66
#  At the time of writing as many as 162952 cases of dengue have been reported; an all time high.
# 66
# 2017-10-31
# ['162952 cases']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 67
#
# Index: 68
# According to the Epidemiology Unit of the Health Ministry, there were 80,732 cases of dengue fever reported between January 1st and July 7th this year.
# 68
# 2017-10-23
# ['80,732 cases']
# []
# ['this year']
# ['January', 'July']
# ['January 1', 'July 7']
# []
# []
# []
# []
# This number includes 215 deaths as a result of the disease, and the worst hit was the Colombo District with 18,186 cases.
# 68
# 2017-10-23
# ['18,186 cases']
# ['215 deaths']
# []
# []
# []
# []
# []
# ['Colombo']
# []
#
# Index: 69
#
# Index: 70
#
# Index: 71
#
# Index: 72
#
# Index: 73
#
# Index: 74
#
# Index: 75
#
# Index: 76
#
# Index: 77
#
# Index: 78
#
# Index: 79
#
# Index: 80
#
# Index: 81
#  According to statistics at the Epidemiology Unit, a staggering 40, 625 dengue cases were recorded for the month of July alone, which is also the highest record for this year.
# 81
# 2017-08-30
# ['40, 625 dengue cases']
# []
# ['this year']
# ['July']
# ['July ']
# []
# []
# []
# []
#  It should also be noted that 144, 052 dengue cases have been reported since January this year.
# 81
# 2017-08-30
# ['144, 052 dengue cases']
# []
# ['this year']
# ['January']
# ['January ']
# []
# []
# []
# []
#
# Index: 82
#
# Index: 83
#
# Index: 84
# Western Province reported 22,186 dengue cases with 17,228 from Gampaha District and�5,616 from Kalutara District adding to the total figure.
# 84
# 2017-08-25
# ['22,186 dengue cases']
# []
# []
# []
# []
# []
# ['Western']
# ['Gampaha', 'Kalutara']
# []
#  3,255 dengue cases were reported from Jaffna, �4,135 from Batticaloa,�4,415 from Trinco,�5,943 from Kurunegala and�6,081 from RatnapuraOut �of around100,000 dengue cases reported so far this yearthere were close to�300�deathsThe Ministry of Health has pointed out that the number of dengue cases identified so far this year has doubled when compared to the total number of dengue cases reported last year.
# 84
# 2017-08-25
# ['3,255 dengue cases', '100,000 dengue cases']
# []
# ['this year', 'this year']
# []
# []
# ['so far', 'so far']
# []
# ['Jaffna', 'Batticaloa', 'Trinco', 'Kurunegala', 'Ratnapura']
# []
#  Out �of around100,000 dengue cases reported so far this year there were close to 300 deaths.
# 84
# 2017-08-25
# ['100,000 dengue cases']
# ['300 deaths']
# ['this year']
# []
# []
# ['so far']
# []
# []
# []
#  �According to statistics from the Ministry of Health�s Epidemiology Unit 105,153 dengue fever cases have been reported across Sri Lanka up to July 24 this year.
# 84
# 2017-08-25
# ['105,153 dengue fever cases']
# []
# ['this year']
# ['July']
# ['July 24']
# []
# []
# []
# ['Sri Lanka']
#  Ministry of Health statistics reveal that Colombo District in the Western Province reported 22,186 dengue cases with 17,228 from Gampaha District and 5,616 from Kalutara District adding to the total figure.
# 84
# 2017-08-25
# ['22,186 dengue cases']
# []
# []
# []
# []
# []
# ['Western']
# ['Colombo', 'Gampaha', 'Kalutara']
# []
#  3,255 dengue cases were reported from Jaffna, 4,135 from Batticaloa, 4,415 from Trinco, 5,943 from Kurunegala and 6,081 from Ratnapura highlight other districts where the dengue menace is prominent.
# 84
# 2017-08-25
# ['3,255 dengue cases']
# []
# []
# []
# []
# []
# []
# ['Jaffna', 'Batticaloa', 'Trinco', 'Kurunegala', 'Ratnapura']
# []
#
# Index: 85
#  Apart from the 202 deaths, the damage to properties and livelihood exceeded a couple of billion rupees.
# 85
# 2017-08-25
# []
# ['202 deaths']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 86
#
# Index: 87
#
# Index: 88
#
# Index: 89
#
# Index: 90
#
# Index: 91
#
# Index: 92
#
# Index: 93
#
# Index: 94
#
# Index: 95
#  Out of this, about 1500 deaths can be prevented every year through improvement of infrastructure facilities to treat heart diseases and critical illness in children.
# 95
# 2017-08-12
# []
# ['1500 deaths']
# []
# []
# []
# []
# []
# []
# []
#  120,000 from all 17,000 patients who have undergone treatment for their cardiac condition at LRH, we could have easily built this complex.
# 95
# 2017-08-12
# []
# ['17,000 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 96
#
# Index: 97
#
# Index: 98
#
# Index: 99
#
# Index: 100
#  Jasinghe said dengue patients being treated at the hospital had dropped to 185, in contrast to some 400 patients receiving treatment daily some time ago.
# 100
# 2017-08-07
# []
# ['400 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 101
#  For the record around 300 dengue related deaths have been reported.
# 101
# 2017-08-04
# ['300 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#  �We have long-term data on the safety of our vaccine for 6 years post vaccination from a Phase IIB efficacy study involving 4002 subjects and for 5 and 4 years respectively from two phase III studies conducted in 10 dengue-endemic countries inAsia and Latin America involving more than 31,000 subjects.
# 101
# 2017-08-04
# ['10 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 102
#
# Index: 103
#  For the record around 300 dengue related deaths have been reported.
# 103
# 2017-08-04
# ['300 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#  �We have long-term data on the safety of our vaccine for 6 years post vaccination from a Phase IIB efficacy study involving 4002 subjects and for 5 and 4 years respectively from two phase III studies conducted in 10 dengue-endemic countries inAsia and Latin America involving more than 31,000 subjects.
# 103
# 2017-08-04
# ['10 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 104
#
# Index: 105
#  Doctors are striking for reasons that aren�t related to their profession while an upsurge of dengue hospitalizes more than 100,000 patients and leaves 300 dead.
# 105
# 2017-07-29
# []
# ['100,000 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 106
#
# Index: 107
#
# Index: 108
#
# Index: 109
#
# Index: 110
#
# Index: 111
#
# Index: 112
#
# Index: 113
#  A record high of 100,000 dengue patients is an indirect consequence.
# 113
# 2017-07-27
# ['100,000 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 114
#
# Index: 115
#
# Index: 116
#
# Index: 117
#  In 2016, 21 deaths were reported in connection with rabies.
# 117
# 2017-07-26
# []
# ['2016, 21 deaths']
# ['2016']
# []
# []
# []
# []
# []
# []
#
# Index: 118
#
# Index: 119
# �Tourism Minister, John Amaratunga told dailymirror that the country hadn�t been able to record the expected tourist arrivals during the month of June mainly due to the floods, dengue outbreak and the garbage crisis�103,114 suspected cases of dengue fever have been reported between January and July 2017 compared to 55,150 cases reported for the year 2016.
# 119
# 2017-07-25
# ['103,114 suspected cases', '55,150 cases']
# []
# ['2017', '2016']
# ['June', 'January', 'July']
# ['June ', 'January ', 'July 20']
# []
# []
# []
# ['country']
#
# Index: 120
#  The Epidemiology Unit told Daily Mirror that there have been 103,114suspected dengue cases reported since 2017 from all over the country.
# 120
# 2017-07-25
# ['103,114suspected dengue cases']
# []
# ['2017']
# []
# []
# []
# []
# []
# ['country']
#  Out of this figure 275 deaths have been reported so far.
# 120
# 2017-07-25
# []
# ['275 deaths']
# []
# []
# []
# ['so far']
# []
# []
# []
#  ��The Western Province has recorded 45,030 cases so far this year, the most number of cases when considering all provinces.
# 120
# 2017-07-25
# ['45,030 cases']
# []
# ['this year']
# []
# []
# ['so far']
# ['Western']
# []
# []
# �There are nearly 4,500 patients and 12 deaths have been reported so far from the Negombo Hospital.
# 120
# 2017-07-25
# []
# ['4,500 patients', '12 deaths']
# []
# []
# []
# ['so far']
# []
# []
# ['Negombo']
#  Although, there are nearly 800 dengue in- house patients now in the Hospital, the beds remaining are only 569.
# 120
# 2017-07-25
# ['800 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#  ��"There are nearly�4,500 patients�and�12 deaths�have been reported so far from the Negombo Hospital"Jan -123, Feb - 95, March - 129, April - 218, May � 467, June � 1884 and July-934 �She mentioned that the issue has emerged following the ongoing construction of the main building of the hospital which will be completed soon.
# 120
# 2017-07-25
# []
# ['4,500 patients', '12 deaths']
# []
# ['Jan', 'Feb', 'March', 'April', 'May', 'June', 'July']
# ['Jan ', 'Feb ', 'March ', 'April ', 'May ', 'June ', 'July']
# ['so far']
# []
# []
# ['Negombo']
#
# Index: 121
#
# Index: 122
#
# Index: 123
#
# Index: 124
#
# Index: 125
#
# Index: 126
#  �We know the virus has taken a heavy toll in Sri Lanka with close to a 100,000 infected and 250 deaths and we are committed to helping Sri Lanka eradicate dengue once and for all,� Bishop said.
# 126
# 2017-07-20
# []
# ['250 deaths']
# []
# []
# []
# []
# []
# []
# ['Sri Lanka', 'Sri Lanka']
#
# Index: 127
#
# Index: 128
# ��The Health Ministry has warned that dengue has now entered a pandemic stage as the resurgence of the mosquito-borne menace has killed over 240 people and affected 80,000 so far in this year compared to a total of 51,000 cases reported in 2016.
# 128
# 2017-07-20
# ['51,000 cases']
# []
# ['this year', '2016']
# []
# []
# ['so far']
# []
# []
# []
#
# Index: 129
#
# Index: 130
#
# Index: 131
#
# Index: 132
#
# Index: 133
#
# Index: 134
#
# Index: 135
#
# Index: 136
#
# Index: 137
#
# Index: 138
#
# Index: 139
# He said as of yesterday the number of patients had increased to 89,885 with 269 deaths.
# 139
# 2017-07-15
# []
# ['269 deaths']
# []
# []
# []
# []
# []
# []
# []
# He said 136 deaths and 37,981 dengue patients were from the Western Province with Southern Province reporting 24 deaths and 10,709 patients while Sabaragamuwa Province reported 27 deaths and 9,688 patients.
# 139
# 2017-07-15
# ['37,981 dengue']
# ['136 deaths', '24 deaths', '10,709 patients', '27 deaths', '9,688 patients']
# []
# []
# []
# []
# ['Western', 'Southern', 'Sabaragamuwa']
# []
# []
# He rejected certain media reports that there were 400,000 dengue patients and added this figure has been mentioned by someone with a demented mentality.
# 139
# 2017-07-15
# ['400,000 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 140
#
# Index: 141
#
# Index: 142
#  In addition, heat-related deaths in the region among the elderly are expected to increase by about 52,000 cases by 2050 due to climate change, according to data from the World Health Organization.
# 142
# 2017-07-15
# ['52,000 cases']
# []
# ['2050']
# []
# []
# []
# []
# []
# []
#
# Index: 143
#
# Index: 144
# e 182 days, there were 77000 dengue patients reported.
# 144
# 2017-07-14
# ['77000 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#  As the disease lasts on average 1 week, on any day in the country there were 77000/182 x 7 = 2962 patients either at home or in hospital.
# 144
# 2017-07-14
# []
# ['2962 patients']
# []
# []
# []
# []
# []
# []
# ['country']
#  All of the dengue viruses in Sri Lanka were inside these 2962 patients (and of course the infected mosquitoes).
# 144
# 2017-07-14
# []
# ['2962 patients']
# []
# []
# []
# []
# []
# []
# ['Sri Lanka']
#
# Index: 145
#
# Index: 146
#  ��According to statistics available with the hospital system, there are as many as 83,000 cases reported so far.
# 146
# 2017-07-13
# ['83,000 cases']
# []
# []
# []
# []
# ['so far']
# []
# []
# []
#
# Index: 147
#
# Index: 148
#
# Index: 149
#  So far this year nearly 76,000 cases of dengue have been reported countrywide with some patients including children succumbing to this lethal affliction.
# 149
# 2017-07-12
# ['76,000 cases']
# []
# ['this year']
# []
# []
# []
# []
# []
# ['country']
#
# Index: 150
#
# Index: 151
#
# Index: 152
#
# Index: 153
#  Last week the ministry said there were about 70,000 victims with some 200 deaths but since then no statistics had been issued.
# 153
# 2017-07-10
# []
# ['200 deaths']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 154
#
# Index: 155
#
# Index: 156
#
# Index: 157
#  Last week the ministry said there were about 70,000 victims with some 200 deaths but since then no statistics had been issued.
# 157
# 2017-07-07
# []
# ['200 deaths']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 158
#
# Index: 159
#
# Index: 160
#
# Index: 161
#
# Index: 162
#
# Index: 163
#
# Index: 164
#
# Index: 165
#
# Index: 166
#
# Index: 167
#
# Index: 168
#  It is reported that nearly 70,000 cases have been detected so far all over the island and it has reached to a deadly disaster with 210 deaths reported within the first half of 2017.
# 168
# 2017-07-03
# ['70,000 cases']
# ['210 deaths']
# ['2017']
# []
# []
# ['so far']
# []
# []
# ['island']
#  ��These larvae who are in the 4th stage can consume 350-400 dengue larvae during their larvae stage and those who are in the stages of 1, 2 and 3 can consume more than 100.
# 168
# 2017-07-03
# ['400 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 169
#
# Index: 170
#
# Index: 171
#
# Index: 172
#  Anil Jasinghe, the Deputy Director GeneralOn average, the hospital houses 375 dengue patients, out of which, 75 are in the latent stage.
# 172
# 2017-06-29
# ['375 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#  At least two patients are being accommodated in one bed.
# 172
# 2017-06-29
# []
# ['two patients']
# []
# []
# []
# []
# []
# []
# []
# ����Medical professionals are doing their best���There are at least two or three patients sharing one bed.
# 172
# 2017-06-29
# []
# ['three patients']
# []
# []
# []
# []
# []
# []
# []
# ����Eradication of dengue must be carried out effectivelyAlthough patients are being accommodated in separate wards depending on their illnesses, we noticed that most beds are shared by two to three patients.
# 172
# 2017-06-29
# []
# ['three patients']
# []
# []
# []
# []
# []
# []
# []
#  Asela Gunawardana��We have 340 dengue patients admitted to the hospital at present.
# 172
# 2017-06-29
# ['340 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#  The ward where her granddaughter was receiving treatment had 40 beds which were outnumbered with over a 100 patients where 60-70 of the patients were suffering from dengue.
# 172
# 2017-06-29
# []
# ['100 patients']
# []
# []
# []
# []
# []
# []
# []
#  The ward housed 42 dengue patients with eight other patients who are at the dengue haemorrhagic stage.
# 172
# 2017-06-29
# ['42 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#  More than three patients were on the floor, due to shortage of beds in the ward.
# 172
# 2017-06-29
# []
# ['three patients']
# []
# []
# []
# []
# []
# []
# []
#  Vajira Dissanayaka��Deputy Director - Colombo North Teaching Hospital, Ragama��There were around 243 dengue patients by Monday with 98 cases with internal bleeding.
# 172
# 2017-06-29
# ['243 dengue', '98 cases']
# []
# []
# []
# []
# []
# []
# ['Colombo']
# []
#  The total number of for a day ranges from 250 to 300 patients whereas the hospital has about 1000 beds.
# 172
# 2017-06-29
# []
# ['300 patients']
# []
# []
# []
# []
# []
# []
# []
# � ���We are now grappling with practical issues in treating patients as our staff has to take hourly measurements from about 40 patients in a ward.
# 172
# 2017-06-29
# []
# ['40 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 173
#
# Index: 174
#
# Index: 175
#
# Index: 176
#
# Index: 177
#
# Index: 178
#
# Index: 179
#
# Index: 180
#
# Index: 181
#
# Index: 182
#
# Index: 183
#
# Index: 184
#
# Index: 185
# With over a whopping 67, 205 cases and some 200 deaths being reported countrywide, the Dengue menace has reached new heights.
# 185
# 2017-06-22
# ['67, 205 cases']
# ['200 deaths']
# []
# []
# []
# []
# []
# []
# ['country']
#
# Index: 186
# There were 587 dengue patients per 100,000 in the Colombo District, Colombo Chief Medical Officer Dr.
# 186
# 2017-06-22
# ['587 dengue']
# []
# []
# []
# []
# []
# []
# ['Colombo', 'Colombo']
# []
#  Wijeymuni said that according to statistics, the Colombo City would have 421 dengue patients per 100,000 of the resident population.
# 186
# 2017-06-22
# ['421 dengue']
# []
# []
# []
# []
# []
# []
# ['Colombo']
# []
#  �However, there had only been 2,740 patients reported from the city.
# 186
# 2017-06-22
# []
# ['2,740 patients']
# []
# []
# []
# []
# []
# []
# []
# Reading out statistics, the CMO stated that there were 298 dengue patients per 100,000 of population across the country.
# 186
# 2017-06-22
# ['298 dengue']
# []
# []
# []
# []
# []
# []
# []
# ['country']
#  However, with at least 45 percent of the patients being reported from Western Province, statistics showed there were 448 dengue patients per 100,000 in the Province.
# 186
# 2017-06-22
# ['448 dengue']
# []
# []
# []
# []
# []
# ['Western']
# []
# []
#  With at least 200 deaths reported due to the epidemic, 50 percent of which was reported from the Western Province, the three deaths reported from Colombo C i t y was a relief.
# 186
# 2017-06-22
# []
# ['200 deaths', 'three deaths']
# []
# []
# []
# []
# ['Western']
# ['Colombo']
# []
# Health sources reported 61,000 dengue patients for the first six months of the year, while 51,000 patients were reported in 2016.
# 186
# 2017-06-22
# ['61,000 dengue']
# ['51,000 patients']
# ['2016']
# []
# []
# []
# []
# []
# []
#
# Index: 187
#
# Index: 188
#
# Index: 189
# The minister accepted that there are instances where two patients occupy one bed.
# 189
# 2017-06-21
# []
# ['two patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 190
#
# Index: 191
#  Samantha Ananda said so far 63,987 dengue patients reported in the country and the total death toll exceeded 200 before the first six months where it was 78 deaths reported for the whole year in 2016.
# 191
# 2017-06-20
# ['63,987 dengue']
# ['78 deaths']
# ['2016']
# []
# []
# ['so far']
# []
# []
# ['country']
#  He said 54,727 patients were reported in 2016.
# 191
# 2017-06-20
# []
# ['54,727 patients']
# ['2016']
# []
# []
# []
# []
# []
# []
#
# Index: 192
#
# Index: 193
#
# Index: 194
#
# Index: 195
#
# Index: 196
#
# Index: 197
#
# Index: 198
#  According to our records, we have between 250�500 cases diagnosed in the last 10 years.
# 198
# 2017-06-14
# ['500 cases']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 199
#
# Index: 200
#
# Index: 201
#
# Index: 202
#
# Index: 203
#
# Index: 204
#  Prachila Samaraweera of the Dengue Control Unit of Colombo, has said some 44,000 dengue patients had been reported countrywide with 115 deaths.
# 204
# 2017-06-07
# ['44,000 dengue']
# ['115 deaths']
# []
# []
# []
# []
# []
# ['Colombo']
# ['country']
#  The number is massive compared to the previous year�s figure where some 55,000 dengue patients were reported with 97 deaths for the entire 2016.
# 204
# 2017-06-07
# ['55,000 dengue']
# ['97 deaths']
# ['2016']
# []
# []
# []
# []
# []
# []
#  The increase in dengue patients is scary when considering that in 2015 there were only 30,000 dengue patients with 54 deaths.
# 204
# 2017-06-07
# ['30,000 dengue']
# ['54 deaths']
# ['2015']
# []
# []
# []
# []
# []
# []
#
# Index: 205
#
# Index: 206
#  �As per statistics collected by the Epidemiology Unit, Ministry of Health Sri Lanka, it is �alarming that during the last 5 months of the year 2017, 52015 suspected dengue cases were reported from all over the island.
# 206
# 2017-06-05
# ['2017, 52015 suspected dengue cases']
# []
# ['2017']
# []
# []
# []
# []
# []
# ['Sri Lanka', 'island']
#
# Index: 207
#
# Index: 208
#
# Index: 209
#
# Index: 210
#
# Index: 211
#  Though there are six main wards in the Prison with nearly 300 patients, there are only three nursing officers.
# 211
# 2017-05-30
# []
# ['300 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 212
# Health Minister Rajitha Senaratne said the US Centre for Disease Control had so far sent out 900 dengue alerts globally with 400 alerts had sent out to countries in the Asian region.
# 212
# 2017-05-27
# ['900 dengue']
# []
# []
# []
# []
# ['so far']
# []
# []
# []
#  Gunawardene had said there were 45,000 dengue patients in Sri Lanka up to now.
# 212
# 2017-05-27
# ['45,000 dengue']
# []
# []
# []
# []
# []
# []
# []
# ['Sri Lanka']
#
# Index: 213
#
# Index: 214
#  Anil Jasinghe, said that currently there were about 100 Dengue patients admitted to NHSL, with about 25 patients who need close monitoring.
# 214
# 2017-05-19
# ['100 Dengue']
# ['25 patients']
# []
# []
# []
# []
# []
# []
# []
# ��He advised the general public to avoid strenuous activities and to seek medical advice in case of a fever, and if hospitalized, to strictly follow the doctor�s advice to drink fluid, because fluid management is a critical part of the treatment of dengue patients�"About 100 Dengue patients have been admitted to NHSL, with about 25 patients who need close monitoring.
# 214
# 2017-05-19
# ['100 Dengue']
# ['25 patients']
# []
# []
# []
# []
# []
# []
# []
#  About 20 new patients are being admitted daily"�2,211 dengue patients admitted so far-Dr.
# 214
# 2017-05-19
# ['2,211 dengue']
# []
# []
# []
# []
# ['so far']
# []
# []
# []
#  Vajira Dissanayake said there were 138 dengue patients in the ward as of midnight on May 14.
# 214
# 2017-05-19
# ['138 dengue']
# []
# []
# ['May']
# ['May 14']
# []
# []
# []
# []
#  A total of 2,211 dengue patients have been admitted to the CNTH within this year, with 22 deaths.
# 214
# 2017-05-19
# ['2,211 dengue']
# ['22 deaths']
# ['this year']
# []
# []
# []
# []
# []
# []
#  � She said wards were overcrowded with more than 90 patients to 40 beds.
# 214
# 2017-05-19
# []
# ['90 patients']
# []
# []
# []
# []
# []
# []
# []
#  �"Wards were overcrowded with more than 90 patients to 40 beds"�Number of patients will increase with rainy seasonDr.
# 214
# 2017-05-19
# []
# ['90 patients']
# []
# []
# []
# []
# []
# []
# []
#  Chandana Kendagamuwa said that by 7 am on May 15, the number of confirmed dengue patients admitted to the hospital was 188, with 56 suspected cases.
# 214
# 2017-05-19
# ['56 suspected cases']
# []
# []
# ['May']
# ['May 15']
# []
# []
# []
# []
#  Only five months of this year have passed and there are over �40,000 dengue patients already.
# 214
# 2017-05-19
# ['40,000 dengue']
# []
# ['this year']
# []
# []
# []
# []
# []
# []
# ���Type 2 dengue, a more virulent virus plaguing the country�- Dr.
# 214
# 2017-05-19
# ['2 dengue']
# []
# []
# []
# []
# []
# []
# []
# ['country']
#  �The Type 2 dengue virus is a virulent virus compared to types 1 and 4.
# 214
# 2017-05-19
# ['2 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#  For seven years, our country has not been exposed to the type 2 dengue virus, so people do not build up immunity to type 2 easily.
# 214
# 2017-05-19
# ['2 dengue']
# []
# []
# []
# []
# []
# []
# []
# ['country']
# � ���"The Type 2 dengue virus is a virulent virus compared to types 1 and 4.
# 214
# 2017-05-19
# ['2 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#  Prachila said that in 2016, 55,000 dengue patients were reported island wide with a death toll of 97 but when the current year is taken into consideration, for just five months, a number of 44,000 dengue patients were reported from across the island with a death toll of 115.
# 214
# 2017-05-19
# ['2016, 55,000 dengue', '44,000 dengue']
# []
# ['2016']
# []
# []
# []
# []
# []
# ['island', 'island']
#  � In 2015, there were reports of 30,000 dengue patients with a death toll of 54.
# 214
# 2017-05-19
# ['30,000 dengue']
# []
# ['2015']
# []
# []
# []
# []
# []
# []
#
# Index: 215
#
# Index: 216
#
# Index: 217
#
# Index: 218
#
# Index: 219
#
# Index: 220
#
# Index: 221
#
# Index: 222
#
# Index: 223
#
# Index: 224
#
# Index: 225
#
# Index: 226
#
# Index: 227
#
# Index: 228
# �Brucellosis, bovine tuberculosis, and a range of food-borne diseases contribute to the morbidity and mortality attributable to zoonotic infections but are struggling to gain the attention of policymakers in the subcontinent, despite it resulting in 150 million illnesses, 175,000 deaths, and 12 million disability-adjusted life years,� the analysis said.
# 228
# 2017-04-14
# []
# ['175,000 deaths']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 229
#  With over 30, 486 cases being reported over the past three months, Dengue has become a widespread� epidemic with approximately over 41.
# 229
# 2017-04-12
# ['30, 486 cases']
# []
# []
# []
# []
# []
# []
# []
# []
#  We had more than 25,000 cases on Dengue fever reported with more than fifty deaths.
# 229
# 2017-04-12
# ['25,000 cases']
# ['fifty deaths']
# []
# []
# []
# []
# []
# []
# []
#  We had more than 25,000 cases reported on Dengue fever with more than fifty deaths"�He said despite experiencing a drought in February, Sri Lanka also experienced several episodes of rain.
# 229
# 2017-04-12
# ['25,000 cases']
# ['fifty deaths']
# []
# ['February']
# ['February']
# []
# []
# []
# ['Sri Lanka']
#  Unlike in the past, we now get too many critical cases and are compelled to accommodate two patients in each bed in the Dengue Management Unit due to lack of beds.
# 229
# 2017-04-12
# []
# ['two patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 230
#
# Index: 231
#
# Index: 232
#
# Index: 233
#
# Index: 234
#
# Index: 235
#
# Index: 236
#
# Index: 237
#
# Index: 238
#
# Index: 239
#  ��In 2016, there had been 54,945 cases reported while only 75 have died.
# 239
# 2017-02-17
# ['54,945 cases']
# []
# ['2016']
# []
# []
# []
# []
# []
# []
#
# Index: 240
#
# Index: 241
#
# Index: 242
# Some 3500 dengue patients have been found during the past three months of this year throughout the country of which 11 patients had died, Coordinator of the Dengue Eradication Unit of the Health Ministry, Dr.
# 242
# 2017-01-21
# ['3500 dengue']
# ['11 patients']
# ['this year']
# []
# []
# []
# []
# []
# ['country']
#
# Index: 243
# Within the year 2016, with the support of the Public Health Department of the Colombo Municipal Council and the Public Health Inspector, UA was able to successfully conduct a total of 57 dengue awareness campaigns, over 60 thalassemia awareness programs and 14 diabetes prevention programmes.
# 243
# 2016-12-30
# ['57 dengue']
# []
# ['2016']
# []
# []
# []
# []
# ['Colombo']
# []
#  As a result of these efforts, 55 dengue prevention programmes were carried out simultaneously on a single day which was asignificant achievement.
# 243
# 2016-12-30
# ['55 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 244
#
# Index: 245
#
# Index: 246
#
# Index: 247
#  He has completely cured eight patients suffering from HIV and nearly 75 patients with Herpes.
# 247
# 2016-12-14
# []
# ['eight patients', '75 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 248
#  He has completely cured eight patients suffering from HIV and nearly 75 patients with Herpes.
# 248
# 2016-12-14
# []
# ['eight patients', '75 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 249
#
# Index: 250
# Having identified the need for affordable healthcare among residents in Pattiwila � where Expack is based � the company carries out a Medicare Clinic thrice a week and has treated 30,000 patients to date.
# 250
# 2016-11-30
# []
# ['30,000 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 251
# To put things into perspective, the first eight months of this year alone over 38,000 cases of dengue were reported along with over 60 dengue-related deaths.
# 251
# 2016-11-23
# ['38,000 cases', '60 dengue']
# []
# ['this year']
# []
# []
# []
# []
# []
# []
#
# Index: 252
#
# Index: 253
#
# Index: 254
#  The virus is unnoticed in 70-80% of the cases, and only 1 in every 5 cases of Zika infections result in Zika fever which is mild.
# 254
# 2016-09-23
# ['5 cases']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 255
#
# Index: 256
#
# Index: 257
#
# Index: 258
#
# Index: 259
#
# Index: 260
#
# Index: 261
#
# Index: 262
#
# Index: 263
# Since the detection of the first dengue case in 1962, this deadly mosquito-borne disease has spread rapidly in Sri Lanka and is reaching epidemic proportions this year with 27,731 cases reported up to the end of June 30.
# 263
# 2016-07-07
# ['27,731 cases']
# []
# ['this year']
# ['June']
# ['June 30']
# []
# []
# []
# ['Sri Lanka']
#
# Index: 264
#  The Lady Ridgeway Hospital which is deemed to be the prime children�s hospital in the country, witness almost 70 dengue cases daily.
# 264
# 2016-07-06
# ['70 dengue cases']
# []
# []
# []
# []
# []
# []
# []
# ['country']
#  �As of May 31, 2016 there have been 1340 dengue cases, out of which 211 were dengue haemorrhagic cases.
# 264
# 2016-07-06
# ['1340 dengue cases']
# []
# ['2016']
# ['May']
# ['May 31']
# []
# []
# []
# []
#  There have been 2 deaths that were caused because the patients were transferred late.
# 264
# 2016-07-06
# []
# ['2 deaths']
# []
# []
# []
# []
# []
# []
# []
#  In 2015, there were 2561 dengue patients admitted to the hospital.
# 264
# 2016-07-06
# ['2561 dengue']
# []
# ['2015']
# []
# []
# []
# []
# []
# []
#  ���We have around 70 cases of dengue everyday and have six special wards where dengue patients are treated.
# 264
# 2016-07-06
# ['70 cases']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 265
#  If we are to put the numbers exactly the cases reported had been 20,731 of which 4,761 cases had been reported from the densely populated Western Province.
# 265
# 2016-06-29
# ['4,761 cases']
# []
# []
# []
# []
# []
# ['Western']
# []
# []
#  More than 160 dengue patients including 12 students had been admitted by Sunday to the IDH Hospital alone which deals mainly with infectious diseases and is situated close to the flood-affected areas.
# 265
# 2016-06-29
# ['160 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 266
# More than 20,000 dengue cases have been reported from all over the country for the past six months claiming 31 lives, the dengue Eradication Programme of the Health Ministry said today.
# 266
# 2016-06-26
# ['20,000 dengue cases']
# []
# []
# []
# []
# []
# []
# []
# ['country']
# A statement issued by the Health Ministry said out of the 20,731 cases reported so far 47.
# 266
# 2016-06-26
# ['20,731 cases']
# []
# []
# []
# []
# ['so far']
# []
# []
# []
# 61 cases had been reported from the Western Province.
# 266
# 2016-06-26
# ['61 cases']
# []
# []
# []
# []
# []
# ['Western']
# []
# []
#
# Index: 267
# More than 500 dengue patients had been admitted daily and during the last six months, 18, 735 suspected dengue cases have been reported to the Epidemiology Unit from all over the island.
# 267
# 2016-06-22
# ['500 dengue', '18, 735 suspected dengue cases']
# []
# []
# []
# []
# []
# []
# []
# ['island']
#
# Index: 268
#
# Index: 269
#
# Index: 270
#
# Index: 271
#  12 patients who came to my clinic voluntarily agreed to take papaya leaves and then take blood tests when it was found that their platelet count and WBC counts had increased with improvement of their overall medical condition.
# 271
# 2016-04-26
# []
# ['12 patients']
# []
# []
# []
# []
# []
# []
# []
#  We examined the thorax of all the patients daily and found that only two patients from the treated group had fluid in their lungs compared to ten in the untreated group.
# 271
# 2016-04-26
# []
# ['two patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 272
#  It said that from January to March this year, 13,275 suspected dengue cases were reported from all parts of the country.
# 272
# 2016-04-02
# ['13,275 suspected dengue cases']
# []
# ['this year']
# ['January', 'March']
# ['January ', 'March ']
# []
# []
# []
# ['country']
#
# Index: 273
#
# Index: 274
#
# Index: 275
#
# Index: 276
#
# Index: 277
#
# Index: 278
#
# Index: 279
# Index: 280
#
# Index: 281
#
# Index: 282
#
# Index: 283
#
# Index: 284
#
# Index: 285
#
# Index: 286
#
# Index: 287
#
# Index: 288
#
# Index: 289
#
# Index: 290
#
# Index: 291
#
# Index: 292
#
# Index: 293
#
# Index: 294
#
# Index: 295
#  The maternal mortality rate, which stood at 92 deaths per 100,000 live births in 1990, plummeted to 33 by 2010.
# 295
# 2015-09-30
# []
# ['92 deaths']
# ['2010']
# []
# []
# []
# []
# []
# []
#  Old diseases like tuberculosis (8,000 cases per year) stubbornly persist.
# 295
# 2015-09-30
# ['8,000 cases']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 296
#
# Index: 297
#  The first nine months of this year recorded 20,058 cases; last year, a peak year for dengue, saw close to 29,000 cases over the same period, according to Health Ministrydata.
# 297
# 2015-09-23
# ['20,058 cases', '29,000 cases']
# []
# ['this year']
# []
# []
# []
# []
# []
# []
#
# Index: 298
#
# Index: 299
#
# Index: 300
#
# Index: 301
#
# Index: 302
#
# Index: 303
#
# Index: 304
#
# Index: 305
#
# Index: 306
#
# Index: 307
#
# Index: 308
#
# Index: 309
#
# Index: 310
#
# Index: 311
#
# Index: 312
#
# Index: 313
#
# Index: 314
#
# Index: 315
#  In 2014 the country reported nearly 40,000 dengue cases, a level of burden that has been consistent over the past few years.
# 315
# 2015-03-11
# ['40,000 dengue cases']
# []
# ['2014']
# []
# []
# []
# []
# []
# ['country']
#
# Index: 316
#
# Index: 317
#
# Index: 318
#
# Index: 319
#
# Index: 320
#  The World Health Organisation (WHO) and others intervened immediately and effectively to limit the number of victims to 284 with 151 deaths.
# 320
# 2014-10-17
# []
# ['151 deaths']
# []
# []
# []
# []
# []
# []
# []
#  As of October 14, there have been 8,914 Ebola cases and 4,447 deaths reported.
# 320
# 2014-10-17
# []
# ['4,447 deaths']
# []
# ['October']
# ['October 14']
# []
# []
# []
# []
#  He said there were about 1000 cases a week now but warned it could soar to between 5000 and 10,000 cases a week by December this year if not effectively checked.
# 320
# 2014-10-17
# ['1000 cases', '10,000 cases']
# []
# ['this year']
# ['December']
# ['December ']
# []
# []
# []
# []
# 		While the WHO and medical scientists have still not found an effective vaccine or drug to prevent or cure Ebola, Sri Lanka�s online Homoeopathy specialist Joe de Livera says �he believes the�homoeopathic remedy Eupatorium Perfoliatum 200, which has cured more than 300 dengue patients, could be tested and used for Ebola patients.
# 320
# 2014-10-17
# ['300 dengue']
# []
# []
# []
# []
# []
# []
# []
# ['Sri Lanka']
#
# Index: 321
#  The World Health Organisation (WHO) and others intervened immediately and effectively to limit the number of victims to 284 with 151 deaths.
# 321
# 2014-10-17
# []
# ['151 deaths']
# []
# []
# []
# []
# []
# []
# []
#  As of October 14, there have been 8,914 Ebola cases and 4,447 deaths reported.
# 321
# 2014-10-17
# []
# ['4,447 deaths']
# []
# ['October']
# ['October 14']
# []
# []
# []
# []
#  He said there were about 1000 cases a week now but warned it could soar to between 5000 and 10,000 cases a week by December this year if not effectively checked.
# 321
# 2014-10-17
# ['1000 cases', '10,000 cases']
# []
# ['this year']
# ['December']
# ['December ']
# []
# []
# []
# []
# 		While the WHO and medical scientists have still not found an effective vaccine or drug to prevent or cure Ebola, Sri Lanka�s online Homoeopathy specialist Joe de Livera says �he believes the�homoeopathic remedy Eupatorium Perfoliatum 200, which has cured more than 300 dengue patients, could be tested and used for Ebola patients.
# 321
# 2014-10-17
# ['300 dengue']
# []
# []
# []
# []
# []
# []
# []
# ['Sri Lanka']
#
# Index: 322
#  Official records show that there were over 32,000 cases of Dengue in urban areas of Sri Lanka last year, in particular, Colombo, where nearly a third of the country�s population is concentrated today.
# 322
# 2014-10-13
# ['32,000 cases']
# []
# []
# []
# []
# []
# []
# ['Colombo']
# ['Sri Lanka', 'country']
#
# Index: 323
#  Official records show that there were over 32,000 cases of Dengue in urban areas of Sri Lanka last year, in particular, Colombo, where nearly a third of the country�s population is concentrated today.
# 323
# 2014-10-12
# ['32,000 cases']
# []
# []
# []
# []
# []
# []
# ['Colombo']
# ['Sri Lanka', 'country']
#
# Index: 324
#
# Index: 325
#
# Index: 326
#
# Index: 327
#
# Index: 328
#
# Index: 329
#
# Index: 330
#
# Index: 331
# � For example, during March and April more than 100 dengue positive patients were admitted to Nawaloka and they recovered completely without any serious complications or deaths.
# 331
# 2014-06-17
# ['100 dengue']
# []
# []
# ['March', 'April']
# ['March ', 'April ']
# []
# []
# []
# []
#
# Index: 332
#
# Index: 333
#
# Index: 334
# 		Up to Monday (19), 40 dengue patients had been admitted to the Ratnapura General Hospital including 30 students from St.
# 334
# 2014-05-22
# ['40 dengue']
# []
# []
# []
# []
# []
# []
# ['Ratnapura']
# []
# 		With eighty patients admitted to the hospital after Monday, about 150 dengue patients were currently receiving treatment at the hospital, the medical superintendent said.
# 334
# 2014-05-22
# ['150 dengue']
# ['eighty patients']
# []
# []
# []
# []
# []
# []
# []
# 		However 12 cases diagnosed as dengue patients are currently under medical treatment at the Ratnapura General Hospital, the health authorities said.
# 334
# 2014-05-22
# ['12 cases']
# []
# []
# []
# []
# []
# []
# ['Ratnapura']
# []
#
# Index: 335
#
# Index: 336
#
# Index: 337
#
# Index: 338
#
# Index: 339
# According to the Epidemiology Unit a total of 34 cases of leptospirosis were reported in Colombo this year.
# 339
# 2014-04-19
# ['34 cases']
# []
# ['this year']
# []
# []
# []
# []
# ['Colombo']
# []
#  It also reported that 708 cases of leptospirosis were detected in the island in March and another 221 in April.
# 339
# 2014-04-19
# ['708 cases']
# []
# []
# ['March', 'April']
# ['March ', 'April']
# []
# []
# []
# ['island']
#
# Index: 340
#
# Index: 341
#
# Index: 342
#
# Index: 343
#
# Index: 344
#
# Index: 345
#
# Index: 346
#
# Index: 347
#
# Index: 348
#
# Index: 349
#
# Index: 350
#
# Index: 351
#
# Index: 352
#
# Index: 353
#
# Index: 354
# What worries the health authorities is the continuous, uncontrolled detection of a 2000 cases more or less each year.
# 354
# 2013-08-20
# ['2000 cases']
# []
# ['2000']
# []
# []
# []
# []
# []
# []
#
# Index: 355
#
# Index: 356
#
# Index: 357
#
# Index: 358
#
# Index: 359
#
# Index: 360
#
# Index: 361
#
# Index: 362
#
# Index: 363
#
# Index: 364
#
# Index: 365
# The Daily Mirror on Wednesday reported the sad news of the loss of 220 precious lives out of 44,395 dengue cases reported last year.
# 365
# 2013-02-07
# ['44,395 dengue cases']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 366
#
# Index: 367
#
# Index: 368
#
# Index: 369
#
# Index: 370
#
# Index: 371
#
# Index: 372
#
# Index: 373
#
# Index: 374
#
# Index: 375
#
# Index: 376
#
# Index: 377
#
# Index: 378
#
# Index: 379
#
# Index: 380
#
# Index: 381
#
# Index: 382
#
# Index: 383
# 14, 500 dengue patients and 80 deaths for the last five months are no forgivable numbers.
# 383
# 2012-06-17
# ['14, 500 dengue']
# ['80 deaths']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 384
#
# Index: 385
#
# Index: 386
# 		Meanwhile the Government Epidemiology Unit (GEU) said 5,802 suspected dengue cases and 24 deaths have been reported countrywide during the first two months this year.
# 386
# 2012-02-22
# ['5,802 suspected dengue cases']
# ['24 deaths']
# ['this year']
# []
# []
# []
# []
# []
# ['country']
#
# Index: 387
#
# Index: 388
#
# Index: 389
#
# Index: 390
# Health authorities have warned that the Ratmalana Railway workshop has been a breeding ground for dengue mosquitoes and that 80 dengue positive patients were reported from the area.
# 390
# 2012-02-02
# ['80 dengue']
# []
# []
# []
# []
# []
# []
# []
# ['Ratmalana']
#
# Index: 391
#
# Index: 392
#
# Index: 393
#
# Index: 394
#
# Index: 395
# In 2010, 22,926 patients and 241 deaths were reported.
# 395
# 2011-12-16
# []
# ['2010, 22,926 patients', '241 deaths']
# ['2010']
# []
# []
# []
# []
# []
# []
#  However, only 22,926 patients and 163 deaths have been reported this year.
# 395
# 2011-12-16
# []
# ['22,926 patients', '163 deaths']
# ['this year']
# []
# []
# []
# []
# []
# []
#
# Index: 396
#
# Index: 397
#
# Index: 398
#
# Index: 399
#  Since then, this time it is one of the major outbreaks of the disease so far in which over 3000 cases are reported from the provincial capital Lahore alone.
# 399
# 2011-09-14
# ['3000 cases']
# []
# []
# []
# []
# ['so far']
# []
# []
# []
#
# Index: 400
#
# Index: 401
#
# Index: 402
# The number of deaths from dengue has risen to a staggering 112 while 13,975 dengue cases have been reported in the first seven months of the year, the Government Epidemiology Unit said yesterday.
# 402
# 2011-08-02
# ['13,975 dengue cases']
# []
# []
# []
# []
# []
# []
# []
# []
# It said the worst affected districts were Colombo with 5,454 cases of dengue and 51 deaths; Gampaha 2.
# 402
# 2011-08-02
# ['5,454 cases']
# ['51 deaths']
# []
# []
# []
# []
# []
# ['Colombo', 'Gampaha']
# []
# 031 cases and 16 deaths; Kalutara 767 cases and six deaths; Kandy 461 cases and two deaths; Galle 453 cases and one death; Matara 298 cases and four deaths, Batticaloa 651 cases and nine deaths, Kurunegala 528 deaths and four deaths, Puttalam 322 cases and six deaths while Ratnapura had 551 cases and three deaths.
# 402
# 2011-08-02
# ['031 cases', '767 cases', '461 cases', '453 cases', '298 cases', '651 cases', '322 cases', '551 cases']
# ['16 deaths', 'six deaths', 'two deaths', 'one death', 'four deaths', 'nine deaths', '528 deaths', 'four deaths', 'six deaths', 'three deaths']
# []
# []
# []
# []
# []
# ['Kalutara', 'Kandy', 'Galle', 'Matara', 'Batticaloa', 'Kurunegala', 'Puttalam', 'Ratnapura']
# []
#
# Index: 403
#
# Index: 404
#
# Index: 405
#
# Index: 406
#  The Municipality�s Chief Medical Officer Pradeep Kariyawasam said there had been 1,477 patients suspected to be suffering from dengue in Colombo but on examining the diagnosis card of each patient it was found that only 769 patients had been confirmed cases of dengue.
# 406
# 2011-06-25
# []
# ['1,477 patients', '769 patients']
# []
# []
# []
# []
# []
# ['Colombo']
# []
#
# Index: 407
#  He said more than 1,000 patients get treatment at the OPD for fever and another 200 admitted daily for further treatment.
# 407
# 2011-06-22
# []
# ['1,000 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 408
#
# Index: 409
#
# Index: 410
#
# Index: 411
#
# Index: 412
#  �There are about 10 to 15 patients being admitted to a hospital each day due to the vast spread of the disease,� CMC Chief Medical Officer, Pradeep Kariyawasam saidHe added that there have been 905 cases of dengue and eight deaths due to the illness reported since January this year and that the numbers are further on the rise due to the heavy rain experienced in some areas.
# 412
# 2011-05-29
# ['905 cases']
# ['15 patients', 'eight deaths']
# ['this year']
# ['January']
# ['January ']
# []
# []
# []
# []
#
# Index: 413
# There were 6,035 cases of dengue reported island wide as at yesterday with 49 deaths as per the data available at the Government Epidemiology Unit.
# 413
# 2011-05-26
# ['6,035 cases']
# ['49 deaths']
# []
# []
# []
# []
# []
# []
# ['island']
#
# Index: 414
# By Yohan Perera The Colombo City is facing the worst dengue epidemic ever Colombo Municipal Council (CMC) said yesterday revealing that there had been 195 cases reported this month.
# 414
# 2011-05-24
# ['195 cases']
# []
# []
# []
# []
# []
# []
# ['Colombo', 'Colombo']
# []
#
# Index: 415
#  According to the latest reports 32 deaths related to Dengue have been reported while 31 deaths have been reported due to Rat fever.
# 415
# 2011-04-26
# []
# ['32 deaths', '31 deaths']
# []
# []
# []
# []
# []
# []
# []
# During the period of January - April this year, a total number of 2785 cases of rat fever have been reported while some 3778 cases of Dengue have been reported to which includes 710 cases in April alone.
# 415
# 2011-04-26
# ['2785 cases', '3778 cases', '710 cases']
# []
# ['this year']
# ['January', 'April', 'April']
# ['January ', 'April ', 'April ']
# []
# []
# []
# []
#
# Index: 416
#
# Index: 417
#
# Index: 418
#
# Index: 419
# 	There were only 36 deaths until the end of November this year and the total number of deaths stood at 58 in 2009.
# 419
# 2010-12-06
# []
# ['36 deaths']
# ['this year', '2009']
# ['November']
# ['November ']
# []
# []
# []
# []
#
# Index: 420
#
# Index: 421
#
# Index: 422
#
# Index: 423
#  According to the latest global figures, in the southeast Asia region (SEAR), till July 10, Indonesia recorded 80,065 cases of dengue, Thailand 57,948 (till August 20), Sri Lanka 28,955 and Myanmar 12,000.
# 423
# 2010-09-11
# ['80,065 cases']
# []
# []
# ['July', 'August']
# ['July 10', 'August 20']
# []
# []
# []
# ['Sri Lanka']
#  In comparison, India recorded around 6,885 cases till August 10, Maldives 550, Bangladesh 76, Bhutan 16, Nepal 2 and Timor Leste 473.
# 423
# 2010-09-11
# ['6,885 cases']
# []
# []
# ['August']
# ['August 10']
# []
# []
# []
# []
#  Figures show Delhi has recorded just over 1,652 cases, which is small when seen in comparison to the population of the state.
# 423
# 2010-09-11
# ['1,652 cases']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 424
#
# Index: 425
#
# Index: 426
#
# Index: 427
#
# Index: 428
#
# Index: 429
#
# Index: 430
#
# Index: 431
#
# Index: 432
#
# Index: 433
#
# Index: 434
#
# Index: 435
#
# Index: 436
#
# Index: 437
#
# Index: 438
#
# Index: 439
#
# Index: 440
#
# Index: 441
#
# Index: 442
# Index: 443
#  Referring to the situation in the school where 20 dengue cases were reported, he said it was found that stagnated water in the basement of the school auditorium may have caused it.
# 443
# 2010-08-08
# ['20 dengue cases']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 444
#
# Index: 445
#
# Index: 446
#
# Index: 447
#
# Index: 448
#
# Index: 449
#
# Index: 450
#
# Index: 451
#
# Index: 452
#
# Index: 453
#
# Index: 454
#
# Index: 455
#
# Index: 456
#
# Index: 457
#
# Index: 458
#
# Index: 459
#
# Index: 460
#  		This year so far, 158 dengue related deaths have been reported while more than 21,000 dengue cases have been reported countrywide.
# 460
# 2010-07-21
# ['158 dengue', '21,000 dengue cases']
# []
# []
# []
# []
# ['so far']
# []
# []
# ['country']
#
# Index: 461
#
# Index: 462
# Papaya leaf juice mixed with honey will increase the blood platelet level of dengue patients, claimed a doctor who had treated 20 patients�using this method.
# 462
# 2010-07-18
# []
# ['20 patients']
# []
# []
# []
# []
# []
# []
# []
#  Ameen, a doctor at the Welipitiya ayurveda hospital has treated 20 patients using this treatment.
# 462
# 2010-07-18
# []
# ['20 patients']
# []
# []
# []
# []
# []
# []
# []
#
# Index: 463
#
# Index: 464
#
# Index: 465
#
# Index: 466
#
# Index: 467
#  At present 19,722 dengue�patients are receiving hospital treatment.
# 467
# 2010-07-11
# ['19,722 dengue']
# []
# []
# []
# []
# []
# []
# []
# []
#
# Index: 468
#
# Index: 469
# Dengue has turned into a widespread island wide epidemic with 19,117 cases and 132 deaths reported yesterday, of which the majority of victims were children.
# 469
# 2010-07-08
# ['19,117 cases']
# ['132 deaths']
# []
# []
# []
# []
# []
# []
# ['island']
#
# Index: 470
#  Pradeep Kariyawasam said that there had been 10 cases of Dengue in the city during the last ten days.
# 470
# 2010-05-30
# ['10 cases']
# []
# []
# []
# []
# []
# []
# []
# []
#  In addition there had been around 50 cases of dengue within the month of May.
# 470
# 2010-05-30
# ['50 cases']
# []
# []
# ['May']
# ['May']
# []
# []
# []
# []
#
# Index: 471
#
# Index: 472
#
# Index: 473
#
# Index: 474
# 	According to statistics, more than 9000 cases of dengue have already been reported isalndwide this year.
# 474
# 2010-03-18
# ['9000 cases']
# []
# ['this year']
# []
# []
# []
# []
# []
# []
#
# Index: 475
# 	The Ministry said that over 9000 cases of dengue have already been reported islandwide with over 500 reported in March alone.
# 475
# 2010-03-15
# ['9000 cases']
# []
# []
# ['March']
# ['March ']
# []
# []
# []
# ['island']
#
# Index: 476
#
# Index: 477
